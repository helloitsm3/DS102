# %% [markdown]
# <img src="https://i2.wp.com/hackwagon.com/wp-content/uploads/2017/02/Logo-Web-Export.png?ssl=1" width=200/>
#
# <h1>Hackwagon Academy DS102 - Problem Set 3</h1>
# <hr>
#
# This Problem Set consists of 20 questions, with each correct answer to be awarded 1 mark, totalling up to 20 marks.
#
# If you have any questions to the Problem Set, feel free to send a message to your TAs or Instructors in the Telegram chat. You are encouraged to also discuss the problem sets within your own groups.
#
# Attempt but minor syntax errors are awarded half the mark.

# %%
#Before you start, please perform the following 2 steps:
#1. Rename the file to FirstName_LastName Hackwagon Academy DS102 - Problem Set 3 e.g. John_Doe Hackwagon Academy DS102 - Problem Set 1

#2. Fill in your details here:
#Name                    : ____LENG WEI SHAO SEAN____

#Start of Course Class(Edit accordingly): __24 May 2020 7.00pm____

# FOR TA/INSTRUCTOR 
# Total Marks:  / 20

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Credits
#
# This problem set is inspired by the [Lending Club Loan Data](https://www.kaggle.com/wendykan/lending-club-loan-data).

# %% [markdown]
# <img src="https://d1ic4altzx8ueg.cloudfront.net/niche-builder/5cb94cef96518.png" width=300>
#
# ## Context
#
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California. It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market.
#
# Your first project is to help LendingClub prepare a prediction model to help them detect loan defaulters. Having already conducted the sufficient exploratory data analysis, your project manager, Silver, wants you to to prepare several machine learning models. Using the dataset which you have preprocessed, `loans_transformed-200k.csv`, you will have to create both <b>supervised and unsupervised machine learning models</b>. Additionally, the `all_loan_desc.csv` dataset prepared for you to prepare a model on the loans descriptions.
#
# There are a total of 4 parts to this problem set:
#
# 1. Naive Bayes Classifier - 8 marks
# 2. K-Means Clustering - 7 marks
# 3. Decision Tree Classifier - 3 marks
# 4. Performance Measures - 2 marks

# %% [markdown]
# ## Naive Bayes Classifier - 8 marks
#
# Another team has prepared for you all of the descriptions within the loans dataset. This dataset has filtered for you rows with descriptions and the target variable the loan status. Your task is to clean it further and use <b>Naive Bayes Classification</b> technique to develop a model for detecting loan defaulters.

# %% [markdown]
# ### Open Loans Decription File
#
# Open the file `all_loan_desc.csv` and store it as `all_desc_df`.

# %%
import pandas as pd

all_desc_df = pd.read_csv("all_loan_desc.csv")
all_desc_df.head()
# Out:
#                                                 desc  loan_status
# 0                                                     Charged Off
# 1                                                      Fully Paid
# 2  I currently have a loan out with CashCall. The...   Fully Paid
# 3                                   Consolidate debt      Current
# 4  This loan will be used solely to consolidate c...   Fully Paid

# %% [markdown]
# ### Q1. Integer Encoding
#
# With the target variable `loan_status`, create a new column called `target`, where if the value contains the word `Charged Off`, `Status:Charged Off` or `Default`, it will be `1`; else it will be `0`. Afterwhich, reduce the dataframe to just the `desc` and `target` columns.
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/ztyxJh0.png">

# %%
def int_encode(input):
    return 1 if ("Charged" in str(input) or "Default" in str(input)) else 0

all_desc_df["target"] = all_desc_df["loan_status"].apply(int_encode)
all_desc_df2 = all_desc_df[["desc", "target"]]
all_desc_df2.head()
# Out:
#                                                 desc  target
# 0                                                          1
# 1                                                          0
# 2  I currently have a loan out with CashCall. The...       0
# 3                                   Consolidate debt       0
# 4  This loan will be used solely to consolidate c...       0

# %%
## TA/INSTRUCTOR ONLY
## MARK AWARDED: /1

# %% [markdown]
# ### Q2. Simple Cleaning
#
# To ensure that your model is efficient, conduct simple cleaning on each description where the descriptions:
#
# 1. Only contains alphanumeric characters (<i>hint: use regular expression</i>)
# 2. Entirely lowercase
# 3. Without trailing or leading spaces
# 4. Not empty strings (<i>hint: use filter</i>)
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/pbLsgSa.png">

# %%
import re

# isStrLower = all_desc_df2["desc"].str.lower()
notEmpty = all_desc_df2["desc"] != " "
onlyAlpha = all_desc_df2["desc"].str.contains('[a-z0-9]', regex=True, na=False)
all_desc_df2["desc"] = all_desc_df2["desc"].apply(lambda x: x.lower())

new_desc_df = all_desc_df2[notEmpty & onlyAlpha]
# Out:
#                                                      desc  target
# 2       i currently have a loan out with cashcall. the...       0
# 3                                        consolidate debt       0
# 4       this loan will be used solely to consolidate c...       0
# 5       i have recently purchased and built a new home...       0
# 6       temporary cash flow challenges. would like thi...       0
# ...                                                   ...     ...
# 126062  i am getting married on july 28 and will need ...       0
# 126063  i would like to buy some new furniture in my a...       0
# 126064  i need to pay $2,100 for fixing my volvo :)  a...       0
# 126065  hi,   i'm buying  a used car. anybody on faceb...       0
# 126066  i need to make several improvements around the...       0
#
# [125777 rows x 2 columns]

# %%
## TA/INSTRUCTOR ONLY
## MARK AWARDED: /1

# %% [markdown]
# ### Q3. Tokenize and Stem Words
#
# For simplicity and lower processing time, you decided to use `PorterStemmer` to stem each word. As such, you would need to reduce each description to their root form.
#
# Steps:
#
# 1. With the `nltk` library, use `word_tokenize` to tokenize each description (a list of words)
# 2. Use the `PorterStemmer` to stem each word (using a for-loop).
# 3. Join up the stemmed words as a string.
#
# All steps above must be done <b>within the same function.</b> Your function should return a string.
#
# Using the `apply()` method, create a new column called `desc_stem` to the `all_desc_df`.
#
# <b>Note: This part might take awhile to run (an average of 3 minutes).</b>
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/XXDqd3i.png">

# %%
from nltk.tokenize import word_tokenize


desc_list = all_desc_df2["desc"].tolist()
tokenized = []

# for i in desc_list:
#     tokenized.append(word_tokenize(i))
    
# tokenized

desc_list
# Out:
# [' ',
#  ' ',
#  "i currently have a loan out with cashcall. the interest rate is 96%! at the time i took out the loan, it helped with a family crisis, but now the interest is crazy to be paying. i'd rather be paying my $200 a month to pay down a loan rather than just the interest.   also, the remainder of my debt has interest rates ranging from 20 - 24%. this includes credit cards, a student loan, and some personal loans. so, i would like to consolidate the rest of my debt and pay a lower interest rate of 15%.  by doing this, i could lower my interest and my monthly payments and save at least $4000 over the next few years.  i do have a bankruptcy that was discharged 3 years ago due to having $40,000 in debt from an uninsured hospital stay. however, i've not missed a payment on anything since.  my credit report does from time time to time relist things as collections and then i have to dispute them as included in bankruptcy and they go back to being listed that way. i'm not sure why the status gets messed up sometimes.   thank you for your time and consideration! ",
#  'consolidate debt',
#  'this loan will be used solely to consolidate credit card debts accrued while wife was/is unemployed.',
#  'i have recently purchased and built a new home that i have always dreamed of having.  i would like to complete the project by putting a hottub in my backyard, however; i am not happy with the rate i  have been offered from ge to finance the spa.  i am paying cash for all other improvements, but this is the final phase and finishing touch to my happiness.  i am in the process of consolidating a lot of debt, and went through a minor period of financial woes, but through determination and hard work i have managed to rebound.  my income is fantastic, and i would pay cash for the item, but would like to reserve the money i have saved for future issues if they should arise.  i am a college graduate, responsible, and work for a very good company that is stable in this very unstable market.  i plan to repay this loan in less than 12 months with a 4th quarter bonus i will be receiving.  thank you for your consideration.',
#  'temporary cash flow challenges. would like this loan to offset mortgage payments-next 90 days. have owned current residence 22years and have never been late on a payment.  i am self employed in the same business for 31 years in the same location. wife works for local school district full time.',
#  'i am looking to pay off my credit card debts.  ',
#  'hi! so $5,500 doesn\'t sound like much to be debt free. well, when you\'re 24 years old it seems like quite a bit. i was foolish enough to buy into those "bad credit auto loans". here is what happened.. i bought an old car. i had an extremely high monthly payment. i missed other payments on other accounts due to having to pay for repairs in addition to my monthly payment.  the money will pay off the existing loan, and also pay off some credit card debt.  i will be debt free except for my payment to you.  i don\'t care what the interest rate is, honestly, as long as it doesn\'t go above 15% (my current car loan rate).   let me know if you can help me. i would really appreciate it. ',
#  'i developed poor credit in college due to not having a job and not being able to pay my credit card bills all the time. i am a recent graduate and am employeed with a very large and prestigous contractor. i have a steady income and want to get out of debt. please help me out. thank you',
#  "1:1 income to debt ratio; this required excellent credit to get into this situation.  paying off a failed business venture from 6 years past, 2 years unemployement (off the books), and 2 years very low wages; all following the fallout of the dot com bust.  i am now, again, gainfully employed in the software industry, with a stable company. (4 years)  i have recently been adversely affected by the cc company's manipulating my credit score, as a result of them cutting my available credit in 1/2, taking my balances from < 40% of available credit, to > 80% of available credit, and tripling my interest rate.  (i thought i had more time :())  funds from this loan will be used to pay off high interest rate credit cards.   this will allow additional monthly income to go towards paying off remaining short term low interest rate credit cards; which will, allow in turn, the early payoff of this loan.",
#  'this loan is to pay off a few debts and put me in the position to start my company as well as buy a property at a really cheap value.. this is a needed step to make all my dreams come true. i have a good job that pays well but i need this beccause this is a one time opportunity. ',
#  "i would like to pay off 3 different credit cards, at 12%, 17% and 22% (after initial 0% period is up).  it would be great to have everything under one loan, making it easier to pay off.  also, once i've paid off or down the loan, i can start looking into buying a house.",
#  'i have problems with one of my loans what i have it is with household-beneficial finance bank it is for $15,250.00 and the interest rate is 25.8% and the payment is 323 monthly and i have 3 months pass due, i page all time in time but the situacion make loss that way cause the gas bill was very higher and the last mont the second day my mother die and was very expensive for us her funeral cause she die here but we bring her body to nicaragua, and the rest is for a loan with american general finance $2,500.00, wells fargo $480.00 , fifth third bank optimun $357.00, all make a total of $18,587.00, please i need cause i get some problems with the big loan with household-beneficial.',
#  "i'm looking to consolidate all of my outstanding credit card debt into one monthly payment with a lower interest rate.",
#  'hello, i have a credit card consolidation loan at 23% interest. please help me to get a better rate!',
#  ' ',
#  ' ',
#  ' ',
#  "my wife and i are having our first child in march 2009, and we need to consolidate a bunch of 20-30% credit card debt that we've been ever so slowly paying down into a manageable lower payment.",
#  ' ',
#  "i recently married and since this was the second time for both of us we decided we would pay everything ourselves. things were going good until my wife was diagnosed with an illness that had prevented her from working. she is back to work now but the bills didn't wait and with the high intrest we have found ourseleves in a bind. ",
#  'to whom it may concern,     hello, my name is david mclean.  i am requesting a loan to consolidate some high interest revolving credit.    the interest rates go anywhere from 14-29.9%.  i am a very reliable person that meets his obligations and pays his debts.   in nearly 15 years, i have not missed or been late on a payment except once due to an oversight.   i have a stable life and home with a good job of nearly 6yrs with plans of retiring from there.  thank you for your thoughtful consideration.',
#  'we knew that using our credit cards to finance an adoption would squeeze us, but then medical and other unexpected expenses made the situation almost impossible. we are a stable family in a stable community. we just need to break a cycle of debt that is getting worse.',
#  "i had a bad year two years ago, with some late and missed payments. i'm doing much better now, but i've got fees and some higher interest bits that have added up on top of the other stuff, and it's a little crazy. i'm hoping doing it thru lending club will make it easier - and cheaper - to pay off.",
#  "lenders,  i have the ability to pay off my current debt but, would like the ability to be able to put some extra money off to the side and build my personal savings account.  the lower interest rate of roughly 7% would enable me to do that.  i'm willing to share my credit report to anyone that is willing to help out. please consider my application.  thank you,",
#  ' i paid off my first prosper loan, but had an emergency and took out a second prosper loan, but at a very high interest rate - and i would like the opportunity to get the interest rate lowered.  this loan would be used to pay off the second prosper loan.  ',
#  ' ',
#  'i want to cut down on my credit  card debt now (while they are not wildly out of control) by consolidating them all in one so i can make regular payments to one single source rather than keeping on track of several credit cards payment.',
#  'i recently proposed to my girlfriend of almost 8 yrs now and everything was going well untill our pug (ody) the middle of my three dogs started limping around and stumbling all the time. well come to find out he has a tumor on his spine. not very good news for us as our dogs are pretty much our children. so the reason for my loan request is the money i spent on the engagement ring was most of my savings and then i had to take out paydayloans loans for the mylogram bill, wich is similar to an mri. $2,700 along with meds, visits etc. well as we all know paydayloans are very high intrest and a pain to try and payback and still stay on top of regular monthly bills. they are taking a toll on me mentally and physically, falling behind on all bills except mortgage. i would use the loan to pay off all payday loans and to catch back up on bills. all was going so well and it now has taken a turn for the worst. if there is any one that can help it would be greatly appreciated, and i would pay the loan back as soon as possible. thank you very much for considering me.',
#  'i would like to consolidate my loan in one small monthly payment w/a low interest rate. all my credit has a very high interest rate. please advise and let me know if i will be qualified.  ',
#  'i would like to refinance my credit cards at a lower rate.  the high interest is making it difficult to keep to my monthly budget.',
#  'i have excellent credit and i need to reduce my credit card debt at a lower interest rate. ',
#  'i have been in business for a year and want to eliminate some personal debt and use the remainder of the loan to take care of business expenses. also lessening the number of trade lines i have open puts me in a better position to pursue business loans since it will  be based on my personal credit. a detailed report can be created to show where exactly the funds will go and this can be provided at any time during the course of the loan. ',
#  'i am building a new garage on a property that i ocupy as my primary residence.  i just purchased the propery in june 2007 and my bank will only offer a peronnal loan a a ridculus high interst rate that would not be cost effective for me.  i have exceptional credit.',
#  ' ',
#  ' ',
#  'well, i am a 44 year old with a family of 5 children (oldest just enlisted in the service) and  good stable job, earning about $85,000 per year. i have two large accounts with a major lender, and a good payment history, yet their interest rate is 18% and 13% respectively on my accounts and i am currently paying a little over $400 a month in interest alone. credit score at or near 700. i am looking for some reprieve from these high interest rates and look forward to becoming debt free asap. i asked the lending institiution and their solution would send my credit score in the tank. i appreciate all your time effort and energy on my behalf.',
#  'thank you for taking the time to consider me and my request as your next investment.  i graduated from college two years ago and moved across the country to start work.  since then, i have been working to pay down the credit card debt that i accumulated while i was a student and as i was establishing a new life.  my salary has allowed me to make my monthly minimum payments on time.  however, i was recently informed by my bank that my interest rates would be rising precipitously.  this has forced me to reevaluate my finances, and i have realized that consolidating my debt with a lower interest rate is imperative if i want to avoid losing many hundreds of dollars a year.  i have a stable income from my job in public service, and i am a responsible borrower who has never been delinquent.  your support in helping me to consolidate this high-interest debt would be greatly appreciated.  thank you again for your time.  ',
#  'would like to pay off 4 small credit cards that have interest rates and other charges that keep escalating.',
#  'this loan will be used to consolidate some of the debt i have and to be add some inventory for my online stores. i recently went back to ebay and i have an amazon.com store. i would like to add some more inventory. recently i paid off a $1750 debt from a payment fraud that i was a victim of. so now to get back in the swing of things and get some inventory for my online store.  ',
#  'i was unemployed for 6 months and relied on a part time job and ran up my credit cards - i would like to condolidate to 1 payment.  i currently work 2 jobs - a full time job and a part time job. i am extremely reliable and want to get my feet back on the ground',
#  "looking to pay off my credit card debt before the interest rate jumps next month.  it's currently at 0% (it was a balance transfer offer) but is scheduled to go to 18.99% next month when the promotional rate expires.",
#  ' ',
#  'already put 19500 into my home addition. the frame and everythingis paid for cash. want to finish the electrical, plumbing, sheetrock. have equity in my house but i was always taught never to take an additional mortgage out.  looking for a good rate and good terms. ',
#  ' ',
#  'i need a loan for my small, opened in september, restaurant. the main purpose is to help the cash flow in my business.',
#  ' ',
#  'in need a little money to get me for a while after a tough semester in both graduate (clinical psychology) and law schools.  any help would be much appreciated.',
#  'i would like to consolidate debt from several credit cards.',
#  ' ',
#  'loan needed to send daughter to medical school. i would ike to use a portion for her tuition and consoidate my debts to make it affordabe. this has been her dream since she was 10',
#  'just want to get these credit cards paid and then toss them away!',
#  'i want to consolidate two credit cards with high interest rates.',
#  ' this loan would be used to replace non deductable interest credit card dept with a collatorlized interest deductable loan.',
#  'i am a great candidate for this loan because i have not missed a beat on any thing in five years. thanks',
#  "please and need to get $10000 to finish my debts i need to pay rent, creadit cards and my car i'm work in the construcction area and because of the economi work is too slow that why i need the money i sure i will pay u every penny back thank you!",
#  ' ',
#  'i need funds to cover the uncovered prescription drugs that i need for my wife.  we have medical insurance but the infamous medicare doughnut hole has bitten us.  for those unaccostumed to the doughnut hole it is when you hit a certain limit, say 2500.00 then until you pay our approx. 45oo.oo, you incurr all the costs of the medicene.',
#  'would like to pay off lowes card with a better interest rate than 19.99%, the current interest rate on the card.',
#  ' ',
#  ' ',
#  'this loan will be used to consolidate high interest credit card debt.    over the course of this past year my wife and i had our first child, purchase a home and received a large bonus from work.  with the new home and the child on the way i chose to spread my tax withholdings on the bonus to all checks received in 2008 this caused my monthly income to fall by $1500.  this in combination with an unexpected additional down payment for our home of $17,000 with only a weeks notice we were force to dip into our credit cards for the past several months.    starting january 1, 2009 i will be able to readjust my tax withholding and start to pay off the credit card debt we have racked up.  this loan will help lower the interest rate during the repayment period and give one central place for payment.  my wife and i have not missed a payment or been late for the past 5 years.  my fico score is 670 mainly due to several low limit credit cards near their max.  i manage the international devision of a software company and my wife is a kindergarten teacher, combined we make 140k a year.    thank you for your consideration and i look forward to working with you.  ',
#  ' ',
#  'i need a lower interest loan to pay off my citifinancial loan.  ',
#  ' ',
#  'i am looking for a loan to pay my credit cards off as well as making some very much needed auto repairs',
#  'i am in my senior year of college in obtaining a bachelors degree in criminal justice.  i do not qualify for financial aid and have used all stafford loans available.  my tuition is approx. $1200 a month and i have 10 courses left which adds up to over $10,000.  i need some assistance to cover my tuition until my graduation date which is august of 2009.',
#  '  borrower added on 12/31/13 > combining high interest credit cards to lower interest rate.<br>',
#  '  borrower added on 12/31/13 > bought a new house, furniture, water softener, a second car, etc. got our lives started and now a manageable monthly payment will help keep them going!<br>',
#  "  borrower added on 12/31/13 > this loan is for debt consolidation - to close credit cards, pay off other debt, finally make a dent in my total debt amount. i already have plans to close all but 2 of my credit cards, and to pay a collection i didn't know about. i want my credit clean with one easy payment.<br>",
#  '  borrower added on 12/31/13 > pay off my other lending club loan and other credit cards<br>',
#  '  borrower added on 12/31/13 > my goal is to purchase a home. i am consolidating my debt to lower interest rate to pay off debt faster. my goal is targeted for february 2015.<br>',
#  '  borrower added on 12/31/13 > just to have one payment each month.<br>',
#  '  borrower added on 12/31/13 > to pay home depot credit services card for my recent kitchen upgrade and pay off my capital one credit card balance<br>',
#  '  borrower added on 12/31/13 > just bought a house, and would like a little extra funds to improve aspects of the house such as, duct work, electrical outlets, backyard, and other minor areas.<br>',
#  '  borrower added on 12/31/13 > i had some water main break and sewer replacement that ran up my credit cards. i want to consolidate the credit cards pay off one loan and refurbish my bathrooms.<br><br> borrower added on 12/31/13 > i had two water main breaks one sewer and one clean water and the cost ran up credit cards expenditures.  i want to consolidate the credit cards with a set payment and upgrade my two bathrooms and water heater.<br><br> borrower added on 12/31/13 > consolidate credet cards and upgrade bathrooms.<br><br> borrower added on 12/31/13 > consolidate credit cards and upgrade two bathrooms.i have been at this job for six years and the job before this one for 24 years. this will make my finances easier to manage. it will provide more efficient bathroom equipment and water heater.<br>',
#  '  borrower added on 12/31/13 > i would like to use this money to payoff existing credit card debt and use the remaining about to purchase a used car that is fuel efficient.<br>',
#  "  borrower added on 12/31/13 > while being in college there were expenses that i had to make. at the moment it seemed easy to buy thing on credit, but now that i'm full-time employee paying all credit cards seem impossible and it'll be great to make one consolidated payment to one firm with knowing its for a set amount of months.<br>",
#  '  borrower added on 12/31/13 > pay down some credit card debt and have some extra money for unexpected expenses.<br><br> borrower added on 12/31/13 > pay down some credit card debt and have some extra money for unexpected expenses. i have been with the same company for 24+ years and i think that shows that i am a responsible person and qualify for this loan.<br>',
#  '  borrower added on 12/31/13 > i am preparing my home for resale. i had an appraisal and a home inspection that revealed a list of items that needed to be address in order that the home sale for the best price. these list included painting, minor repair, flooring, and landscaping.<br>',
#  '  borrower added on 12/31/13 > payoff high interest<br>',
#  '  borrower added on 12/31/13 > consolidation<br>',
#  '  borrower added on 12/31/13 > i would like to payoff my debt. i want to be debt free other than my mortgage and student loans in 3 years. this loan will give me the opportunity to pay off two credit accounts. if you look at my credit report i always pay on time and never miss payments. thank you.<br>',
#  '  borrower added on 12/31/13 > payoff 2 credit cards.<br>',
#  '  borrower added on 12/31/13 > i am looking to pay off this loan in 2 years instead of the 3 given. i have made all ontime payments to a wedding loan for the past years and will have that paid off in 2014.<br>',
#  '  borrower added on 12/31/13 > i hope to save money by consolidating my debts.<br>',
#  '  borrower added on 12/31/13 > basically to pay down one credit card in particular and to handle some household expenses<br>',
#  '  borrower added on 12/31/13 > i needed to consolidate my debt and save on monthly payments.<br>',
#  '  borrower added on 12/31/13 > to pay off outstanding credit card debt quicker than just making the minimum payment each month.<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > to whom it may concern i will be using this lone to pay my credit cards witch by the way i have never been late on. i will allso be paying another privit lone that i do not get along with person anymore. this will pay down my debt to zero and this lone will be all i have.     thankyou<br>',
#  '  borrower added on 12/31/13 > to help get myself out of debt.  i am in a situation that i need to move out of a rent free place and into my own place.  my monthly bills are too high to pay and to pay a rent<br>',
#  '  borrower added on 12/30/13 > i have three credit cards, one is a store card. unfortunately all three have over 20%+ interest rates. this would help me save a lot of money and help me better pay them down with only one monthly payment instead of three separate payments.<br>',
#  '  borrower added on 12/30/13 > pay off credit cards<br>',
#  '  borrower added on 12/30/13 > this loan will pay off higher percentage credit card debt and consolidate the debt into one monthly payment.  thank you.<br>',
#  '  borrower added on 12/31/13 > debt consolidation, some home repairs<br><br> borrower added on 12/31/13 > debt consolidation, some home repair<br>',
#  '  borrower added on 12/30/13 > refinance my credit cards due to an extremely high apr<br>',
#  '  borrower added on 12/31/13 > i have been working for the same employer for five years. i am requesting a loan to pay off high interest credit cards to eliminate debt.<br>',
#  '  borrower added on 12/30/13 > this loan is to consolidate my credit card debt.<br>',
#  '  borrower added on 12/30/13 > metal roof<br>',
#  '  borrower added on 12/31/13 > pay off credit cards that were run up primarily as a result of a major health event with my daughter<br>',
#  '  borrower added on 12/30/13 > credit card consolidation, looking to pay down balances quicker<br>',
#  '  borrower added on 12/31/13 > i am requesting this loan for one reason-debt consolidation. though it is a singular reason, i understand the numerous benefits of having an endpoint in sight.   i will be able to make the payments in a timely manner and i will do so if given the opportunity. thank you for your consideration.<br>',
#  '  borrower added on 12/30/13 > pay off previous lending club loan at a lower rate and consolidate other debt at a lower rate.<br>',
#  '  borrower added on 12/30/13 > i have 8 different credit cards and pay $100.00 to each credit card and would like to consolidate to one and pay more.<br>',
#  '  borrower added on 12/30/13 > to pay off cards and all debt except car.   my mother had medical bills. i just paid off my last lending club loan.  thanks for considering my loan investment.<br>',
#  '  borrower added on 12/30/13 > my loan will be used to refinance my credit card that has a high apr. i will be able to pay it off within the 36 months requested because i am employed full time.<br>',
#  '  borrower added on 12/31/13 > pay off high interest credit cards and do home improvements<br>',
#  '  borrower added on 12/30/13 > to pay off high interest credit card loans.<br>',
#  '  borrower added on 12/30/13 > i am eager to pay down high revolving credit balances to finally experience financial freedom.  a working professional, i make all of my payments on time but am eager to be rid of debt and interest and take control of my financial future. this loan will help me reach this goal more quickly.<br>',
#  '  borrower added on 12/30/13 > i will be moving soon and need funds to pay for the move, furnish the apartment, and pay deposit/first month rent including other incidental expenditures.<br>',
#  '  borrower added on 12/31/13 > i have 4 credit cards that i need to pay off and cut up. i just paid off my auto loan and want to get the rest of my debt paid off as soon as possible. the higher interest rates on the cards are making it tough to pay them off.<br>',
#  '  borrower added on 12/30/13 > with the approval of this loan, i hope to pay off several past due medical bills in addition to paying of some credit cards that were also used to pay for medical expenses.<br>',
#  '  borrower added on 12/31/13 > this loan will finally pay off my high interest credit card debt and help me build my credit even higher!!!<br>',
#  '  borrower added on 12/30/13 > i have 2 existing p2p loans ,one from 2011 the other from 2012 <br> both current and close to payoff.<br>the majority of the money is to payoff and consolidate the two existing p2p loans, leaving reserve for other expenses and allowing me one single payment instead of three separate payments.<br>',
#  '  borrower added on 12/31/13 > to pay off credit cards and have a lower interest rate to payoff quicker will be my goal.<br>',
#  '  borrower added on 12/30/13 > loan is for debt consolidation.<br><br> borrower added on 12/30/13 > debt consolidation<br><br>  borrower added on 12/31/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > this  loan is for debt consolidation and this whole process was extremely easy.<br><br>  borrower added on 12/31/13 > this has been a great experience and really glad i received the offer letter in the mail.<br>',
#  '  borrower added on 12/30/13 > debt consolidation and bathroom remodel<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > i owe close 4000.00 in credit cards and the irs 5000.00. i would like to pay this amount in full. i pay 460.00 a month and it seems like its not going down. i would like to have extra money. i pay my bill on time and never had an issues. thank you<br><br> borrower added on 12/30/13 > i owe close 4000.00 in credit cards and the irs 5000.00. i would like to pay this amount in full. i pay 460.00 a month and it seems like its not going down. i would like to have extra money. i pay my bill on time and never had an issues. thank you<br>',
#  '  borrower added on 12/31/13 > would like to eliminate some credit card debt and save money each month to put towards reducing mortgage.<br>',
#  '  borrower added on 12/30/13 > home improvement &amp; debt consolidation.<br>',
#  '  borrower added on 12/31/13 > my loan is for debt consolidation, i would like to make one monthly payment instead of 6 payments to 6 different creditors.<br>',
#  '  borrower added on 12/30/13 > bill consolidation loan.  want to pay off high interest accounts.<br>',
#  '  borrower added on 12/30/13 > my loan is to consolidate all my unsecured debt.<br>',
#  '  borrower added on 12/30/13 > just want to get some nagging bills paid off<br>',
#  '  borrower added on 12/30/13 > i want to pay all my debts creditcards etc<br>',
#  '  borrower added on 12/30/13 > we are going to use these funds to pay off all of our credit cards<br>',
#  '  borrower added on 12/30/13 > pay credit cards and destroy cards in 3 years out of debt<br>',
#  '  borrower added on 12/30/13 > i need the loan to pay off credit cards as well as other small loans i owe.<br>',
#  '  borrower added on 12/30/13 > credit card consolidation.<br>',
#  '  borrower added on 12/30/13 > this loan will be used to take care of the credit card debt that i have incurred trying to live my life while helping others.  i realize that living by credit card is no way to live and if i do not have the money i should not use it or loan it by getting a cash advance.  i must live within my means.<br>',
#  "  borrower added on 12/30/13 > thank you for your time &amp; consideration.  this debt consolidation loan is to pay off the last few higher interest accounts i have.  i'm in the process of streamlining debt to pay it down as effectively as possible, due to a big set back i had a few years back.  thank you &amp; happy new year!<br>",
#  '  borrower added on 12/30/13 > i am paying off my credit card and financing part of my upcoming june 2014 wedding.<br>',
#  '  borrower added on 12/30/13 > pay my credit cards.<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > i am looking to consolidate my debt for two main reasons. 1. i want to be able to avoid paying high interest rates to credit cards over an extended time period. 2. i want to have one place to pay and a set date of when the monies owed will be paid in full.<br>',
#  '  borrower added on 12/30/13 > i plan on using the money to pay off credit cards.  at the moment i make minimum payments totaling $594.43 at high interest rates. with this loan i will be able to pay off these credit cards now and be credit card debt free in five years.  i have been at my current job for almost nine years.<br>',
#  '  borrower added on 12/30/13 > looking to consolidate a few credit cards and complete some home improvement projects that have been started.<br>',
#  '  borrower added on 12/30/13 > to pay my credicards deb<br>',
#  '  borrower added on 12/30/13 > loan is for motorcycle financing of a 2007 triumph thruxton<br>',
#  '  borrower added on 12/30/13 > conslidation<br>',
#  '  borrower added on 12/31/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > debt consolidation.<br>',
#  '  borrower added on 12/31/13 > to handle several high interest cards, and to pay off little amounts on other cards, and also to have a small buffer.<br>',
#  '  borrower added on 12/30/13 > i would like this loan to consolidate my credit card bills into one monthly payment.  a consolidation loan will allow me to manage my monthly debt better and save money faster.<br>',
#  '  borrower added on 12/30/13 > i have four credit cards that i have been paying on for several years and even though i pay over the minimum amount due each month, the principle is not moving. the debt has been a thorn in my side for several years, and never seems to go away. i will use funds to pay off and close the accounts<br>',
#  '  borrower added on 12/30/13 > i have several high interest loans and credit cards that i wish to pay off. my goal is to be debt free, except for my mortgage and lending club loan, by the end of 2014.<br>',
#  '  borrower added on 12/30/13 > the loan is being used to combine multiple smaller loans into one monthly payment.  we have always took care of any debts due.  lending club has been great to work with.  the loan process is very easy.<br><br> borrower added on 12/30/13 > the loan is being used to pay off multiple smaller debts into one monthly payment.  my employment is very stable and can be verified.  paying on our debts is very important to us.   lending club has been great to deal with and is very easy to use.<br>',
#  "  borrower added on 12/30/13 > i would like to pay off cash call loan and consolidate credit cards. i have a loan with you for the last year.  i've never missed a payment in my life on any credit cards or loans.<br>",
#  '  borrower added on 12/30/13 > this is to consoliate debt and do repairs to my home-<br>',
#  '  borrower added on 12/30/13 > the funds will be used to consolidate debt. since i pay my bills on time, this loan will enable me to be free of debt in a relatively short time<br>',
#  "  borrower added on 12/30/13 > i have too much credit card debt and payments, i would love to be able to pay them off and cut them up. its too bad you couldn't lend me enough to pay off my car too. thank you<br>",
#  "  borrower added on 12/30/13 > it's mostly to fix my credit by paying my credit cards off<br>",
#  '  borrower added on 12/30/13 > my loan is to do needed repairs on the main bathroom of my home. plumbing and bathroom fixtures need to be up dated.<br>',
#  '  borrower added on 12/30/13 > to consolidated all credit cards in one payment<br>',
#  '  borrower added on 12/30/13 > to pay off credit cards. for debt consolidation<br>',
#  '  borrower added on 12/30/13 > to consolidate credit card debt and payoff remaining taxes owed to improve cash flow substantially.i pay my obligations on time and i budget prudently.<br>',
#  '  borrower added on 12/30/13 > looking for a simpler way to pay off my remaining debt with one, easy payment per month instead of several payments that are scheduled on different days.  hopefully, with this loan, i will be able to minimize the chaos of cleaning up past credit history.<br>',
#  '  borrower added on 12/30/13 > personel<br>',
#  '  borrower added on 12/30/13 > i want to payoff all credit card bills off and cut them up so i can pay with one ck and have them paid off in five years then i can start saving alittle money back so tire of writing 10 to 15 cks a month<br>',
#  '  borrower added on 12/30/13 > need to consolidate current debt in order to purchase home<br>',
#  '  borrower added on 12/30/13 > pay off credit cards and have one payment<br>',
#  '  borrower added on 12/31/13 > to add more revenue generating channels to an existing and growing solar company through opening a new retail store and building an online shopping feature and infra structure related to warehousing, procurement and order filling, packing and shipping.<br>',
#  '  borrower added on 12/30/13 > to pay off high interest credit cards<br>',
#  '  borrower added on 12/30/13 > i purchased my first home in 2012.  i immediately tackled the outdated kitchen and bought furniture to turn the empty house into a home.  but with a new home and new projects came new debt.  my goal (with the help of lendingclub) is to be debt free by the end of 2014.<br>',
#  '  borrower added on 12/30/13 > i will be performing critical exterior repairs to my home to include facia and siding as well as decking,, i will also be removing 2 pine trees in the back yard<br>',
#  '  borrower added on 12/30/13 > my goal for applying for this loan is to start on a path to financial freedom by paying off all credit cards and save money over the long term. this will help gain the footing i need to achieve my goal of being debt-free in 36 months! thanks for the opportunity to take that first step to freedom!<br>',
#  '  borrower added on 12/30/13 > consolidation of credit cards<br>pay off refrigerator<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > it is to pay off credit card balances that have 13.9 and 15.9% interest rates on them<br>',
#  '  borrower added on 12/30/13 > pay off credit card debts<br>',
#  '  borrower added on 12/30/13 > payoff credit cards and thereby reduce my monthly obligations.<br>',
#  "  borrower added on 12/30/13 > a few months ago i started a new job that i love and recently moved to a new neighborhood. i'm looking for a small loan to help consolidate credit card debt relating to the move.<br>",
#  '  borrower added on 12/31/13 > credit card consolidation and payment<br>',
#  '  borrower added on 12/30/13 > i am consolidating debt. i have had continuous employment for 6 years, in a 40 hour a week salaried position for a fortune 100 company. (prior i was a full time student). i have student loans as well as a car loan. i have never missed a payment on any of my debt.<br>',
#  '  borrower added on 12/30/13 > pay off all dept and make one monthly payment<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  "  borrower added on 12/30/13 > i've been carrying high-interest debt balances for far too long and need to finally break the vicious cycle. lending club seems to be a great way to do just that. i am much happier to pay a small bank or individual than any of these larger banks monopolizing our country. thank you.<br>",
#  "  borrower added on 12/30/13 > i have a new home and it's in need of a new roof immediately.<br>",
#  '  borrower added on 12/30/13 > payoff all high interest rate credit cards<br>',
#  '  borrower added on 12/30/13 > consoladation loan.<br>',
#  '  borrower added on 12/30/13 > to consolidate my visa, and pay on other charge card<br><br>  borrower added on 12/30/13 > to consolidate my visa, and pay on other charge card<br>',
#  '  borrower added on 12/30/13 > to consolidate the majority of my bills and to pay off property taxes.<br>',
#  '  borrower added on 12/30/13 > to pay off 10 credit cards manage my money eaiser<br>',
#  '  borrower added on 12/30/13 > home improvement<br>',
#  '  borrower added on 12/30/13 > pay off some credit card debt and do some home improvements<br>',
#  '  borrower added on 12/31/13 > i am trying to pay off all my credit cards,tax bill and auto loan so i only have 1 payment every month , i pay my bills on time and will hopefully be able to pay even more every month with a loan from lending club<br>',
#  '  borrower added on 12/30/13 > this loan will be for debt consolidation, in order to lower the amount of money being spent on small bills.<br>',
#  '  borrower added on 12/30/13 > credit card refinnace<br><br> borrower added on 12/30/13 > i will pay off all credit  cards accounts<br><br> borrower added on 12/30/13 > this loan is for pay off credit cards.<br>',
#  '  borrower added on 12/30/13 > i want to set a plan to pay off all my debt with one payment. my new years resolution is to set a plan for financial freedom.<br>',
#  '  borrower added on 12/30/13 > today, i very happy get the loan with rate apr: 7.99%, and now i will payoff another credit card<br>',
#  '  borrower added on 12/30/13 > pay off credit cards<br>',
#  '  borrower added on 12/30/13 > credit card refinancing.  i have several cards with high rates (some 29.99%) were i have made excellent payments to build my credit.  i have built my credit now, and i would like the one payment with lower rates, and cancel all the high rated accounts.<br>',
#  '  borrower added on 12/30/13 > i have been in business for several years and need the loan so i can expand the business.<br>',
#  '  borrower added on 12/30/13 > my loan is to consolidate my debt.<br>',
#  '  borrower added on 12/30/13 > the loan is needed to consolidate debt at a lower interest rate.<br>',
#  '  borrower added on 12/30/13 > i will be consolidating all of my smaller loans.  this will allow me to have a smaller monthly payment and have only one payment to you.  paying off capital one, smfcu, lowes, wal-mart, h&amp;r block visa, ge money both accts, northwest and credit one.  this will save me monthly payments.<br>',
#  '  borrower added on 12/30/13 > my loan is for consolidation<br>',
#  '  borrower added on 12/30/13 > to consolidate credit card debt so that i can be debt free much faster than if i pay the credit cards individually.<br>',
#  '  borrower added on 12/30/13 > this loan will help me pay my debt. i think applying for this lending club loan is a prudent decision i am making as it will help me get over my debt slowly but surely.  my commitment would be to pay my loan on time and improve my credit score.<br><br> borrower added on 12/30/13 > this loan will help me pay my debt. i think applying for this lending club loan is a prudent decision i am making as it will help me get over my debt slowly but surely.  my commitment would be to pay my loan on time and improve my credit score.<br><br>  borrower added on 12/31/13 > this loan will help me pay my debt. i think applying for this lending club loan is a prudent decision i am making as it will help me get over my debt slowly but surely.  my commitment would be to pay my loan on time and improve my credit score. thank you  ,<br>',
#  '  borrower added on 12/30/13 > consolidating some credit card debt to simplify my monthly bills and budget. this will also save me some money, as well, win win!<br>',
#  "  borrower added on 12/30/13 > it's funny how sometimes you worry about how you are going to pay the next bill. you may toss and turn, and have many a restless night. when you think that you have exhausted all possibilities, and are ready to throw in the towel, something arrives in the mail that offers a beacon of hope.<br>",
#  '  borrower added on 12/30/13 > i would like to consolidate my revolving accounts. i have stability at my employer and have worked hard to pay my bills on time. this would allow for simplifcation in budgeting in order to achieve future financial success.<br>',
#  '  borrower added on 12/30/13 > i have credit card debt that needs to be payed off. this loan payment will be less than the cars payments combined.<br>',
#  '  borrower added on 12/30/13 > i recently got a loan to help pay for some educational classes.  the terms on that loan are not very good.  i would prefer to have better terms.  this education should allow me to get a better position very soon with better pay.<br>',
#  '  borrower added on 12/30/13 > this loan is to pay off high interest rate credit card debt in a more timely and responsible manner.<br>',
#  '  borrower added on 12/30/13 > we are making significant improvements to our home that will increase the value. in addition to the home improvement, i will use it to pay off the small amount of credit card debt i have.i well-paying position that i have been in for 10 years and have no late payments on my record.<br>',
#  '  borrower added on 12/30/13 > consolidate all credit cards and loans to lower monthly payments<br>',
#  '  borrower added on 12/30/13 > the reason for this loan is to consolidate my debt i plan to pay this loan in a couple of months<br>',
#  '  borrower added on 12/30/13 > i would like to refinance and do some more home improvement<br>',
#  '  borrower added on 12/30/13 > to kill credit card debt<br>',
#  '  borrower added on 12/30/13 > pay off credit cards<br>',
#  '  borrower added on 12/30/13 > to pay off high interest credit cards so that i may buy my very first home in the near future. i intend on making double payments when possible and will pay off this loan in less than 2 years.<br>',
#  '  borrower added on 12/30/13 > the loan is to consolidate tax and other debt. i am able to comfortably pay my current obligations but the interest rate will be lower with this loan.  the tax debt is a result of a failed tech company from nine years ago.  my current employment and income are stable.<br>',
#  '  borrower added on 12/30/13 > what to payoff all high interest credit card and bring muy credit score to purchase house<br>',
#  '  borrower added on 12/30/13 > need to conbine credit cards to get rid of them faster<br>',
#  '  borrower added on 12/30/13 > credit card consolidation. pay all credit cards in full.<br>',
#  '  borrower added on 12/30/13 > debt consolidation.<br>',
#  '  borrower added on 12/30/13 > unexpected repairs and credit card pay off<br>',
#  '  borrower added on 12/30/13 > consolidate high interest credit cards and start 2014 by getting out of debt!<br>',
#  '  borrower added on 12/30/13 > consolidating and removing credit card debt<br>',
#  '  borrower added on 12/30/13 > to pay of debt for credit cards<br>',
#  '  borrower added on 12/30/13 > my requested loan is to take advantage of the lower available interest rate available through lending club to consolidate several lines of credit down into one for simpler, dependable, and less interest-burdened payoff.<br>',
#  "  borrower added on 12/30/13 > to get out of debt<br><br>  borrower added on 12/30/13 > i plan to use this money to pay off all my debts and stop living from pay check to pay check .i have a very stressfull job and i need a break .i'm tired of working so hard and taking all my money to pay bills.a new year will be here soon i would like to be debt free<br>",
#  '  borrower added on 12/30/13 > i have debt that i am trying to pay off on high interest credit cards. despite making sizable payments towards them i am unable to lower my balances due to their high rates. i would like to consolidate my debt on a lower interest rate in an effort to eliminate my credit card debt.<br>',
#  '  borrower added on 12/30/13 > i have credit card debt that i want to pay off in the next three years with a better interest rate. i also wanted to possibly invest in a new lap top to be able to do more work when i am on the road.<br>',
#  '  borrower added on 12/30/13 > want to buy an atv.<br>',
#  '  borrower added on 12/30/13 > i am slowly coming out of debt. i always make my payments &amp; extra, but it is taking too long so i am using this consolidation to speed up my debt free life and cost less in interest.<br>',
#  '  borrower added on 12/30/13 > i really want to consolidate and have one payment and to be debt free at the end of this loan.  :)<br>',
#  '  borrower added on 12/30/13 > this loan is to pay off my highest balance, highest interest rate credit card.  getting that balance consolidated will help me eliminate my debt in the next few years.<br>',
#  '  borrower added on 12/30/13 > i am a home owner looking to relocate, as i have outgrown my current home. i will use this loan for cosmetic repairs of the current home so that i can sell, and relocate to a home more suited to my needs.<br>',
#  '  borrower added on 12/30/13 > i have two credit cards which i would like to pay off. i have been making all my payments on time with little to show for it except the same amount owed month after month. this of course is due to the accrued interest tagged on plus the fees they charge. this is the last step to get on track for 14<br>',
#  '  borrower added on 12/30/13 > my loan is for debt consolidation to have a smaller monthly payment.<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > bill consolidation<br>',
#  '  borrower added on 12/30/13 > i would like to be debt free in the next four years. this loan will help me on the path to get my finances in order.<br>',
#  '  borrower added on 12/30/13 > i pay to hi interest<br>',
#  '  borrower added on 12/30/13 > pay off credit cards<br>',
#  '  borrower added on 12/30/13 > wanted to consolidate all of my credit cards to one monthly payment.<br>',
#  '  borrower added on 12/30/13 > seeking a loan with good terms.<br>',
#  "  borrower added on 12/30/13 > i'm glad to be getting rid of my high interest rate credit cards<br>",
#  '  borrower added on 12/30/13 > consolidate a few bills including the old lending club loan and pay off my car.<br>',
#  '  borrower added on 12/30/13 > this is to refinance some student loans and some old credit debt.<br>',
#  '  borrower added on 12/30/13 > i need this to consolidate credit cards and a personal loan with my credit union.<br>',
#  '  borrower added on 12/30/13 > consolidation and home repairs<br><br> borrower added on 12/30/13 > would like to consolidate some credit cards and put the rest in to home repairs, (interior paint and new a/c.<br>',
#  '  borrower added on 12/30/13 > refinance high interest credit cards<br>',
#  '  borrower added on 12/30/13 > debt consolidation<br>',
#  '  borrower added on 12/30/13 > i would like to consolidate my bills and pay only one monthly bill.<br>',
#  '  borrower added on 12/30/13 > i would like to refinance my credit card debt at a lower rate so i can pay off the balance sooner. i had a previous lending club loan and paid it in full in 1/3 the time!<br>',
# ...
#  '  borrower added on 12/23/13 > debt consolidation of minimal credit cards and back taxes.<br>',
#  '  borrower added on 12/23/13 > credit card refinancing<br>',
#  '  borrower added on 12/23/13 > this will payoff all debt and allow for a few home improvements so i have 1 monthly payment.<br>',
#  '  borrower added on 12/23/13 > i need this loan to help with business expenses for my small business.  i need to purchase marketing material, a laptop and extra money for any start up cost.<br>',
#  '  borrower added on 12/23/13 > to pay off all my credit cards with high interest rates<br>',
#  '  borrower added on 12/23/13 > i will be repaying all my credit cards with this. i make payments on them regularly. i have been paying them off with a loan from my 401k every year. this will be the last step towards becoming debt free. i have had my job since graduating from grad school in 2008.<br>',
#  '  borrower added on 12/23/13 > to consolidate my credit card debt<br>',
#  '  borrower added on 12/23/13 > i want to take my dad to brazil for the world cup and fulfill a lifelong dream of his.  he has helped me through getting both of my degrees, has always been there for me and i want this to be the trip of a lifetime<br>',
#  '  borrower added on 12/23/13 > i am trying to pay high interest cards.<br>',
#  '  borrower added on 12/23/13 > just to balloon my credit cards into one place so that i can continue to have outstanding credibility with my lenders/creditors. others trusting in me is my ultimate goal with finances as well as in every day life!<br>',
#  '  borrower added on 12/23/13 > to consolidation my debt<br>',
#  '  borrower added on 12/23/13 > this loan is to consolidate my high interest credit card debt.<br>',
#  '  borrower added on 12/23/13 > i am a first time home buyer and closed sale late june this year. front yard looked terrible when i got here and has to be completely re-done. i also plan on applying loan toward flooring and energy saving repairs.<br>',
#  '  borrower added on 12/23/13 > hi, looking to pay off my citibank card and furnace loan. thank you.<br>',
#  '  borrower added on 12/23/13 > need to consolidate credit card to one payment. also need home improvement. (roof0<br><br> borrower added on 12/23/13 > consolidate credit card debt. home improvement (roof)<br><br> borrower added on 12/23/13 > home improvement of new roof on home and pay off credit card<br>',
#  '  borrower added on 12/23/13 > pay off credit card debt to prepare for home purchase next year.<br>',
#  '  borrower added on 12/23/13 > pay off and close higher interest rate credit cards.<br>',
#  '  borrower added on 12/23/13 > i want to repay my credit cards and pay off my bank loans.<br>',
#  '  borrower added on 12/23/13 > pay off debt<br>',
#  '  borrower added on 12/23/13 > living and working in the most expensive place in the us, we still managed to buy a property this year! now with credit cards refinanced, we are on track for the best year of the horse ever!! thanks for making it happen!<br>',
#  '  borrower added on 12/23/13 > my loan is to payoff my credit cards that the interste are to high, and have only one dept on my payment<br>',
#  '  borrower added on 12/23/13 > this is for debt consolidation.  we have several small accounts and a couple of larger ones we would like to pay off and then we would reduce the amount of payments we need to make per month.<br>',
#  '  borrower added on 12/23/13 > pay off high interest credit cards and a couple of small loans.<br>',
#  '  borrower added on 12/23/13 > i have some credit card debt, and 2 medical bills that cumulatively are sapping my income. i need to consolidate so i can pay down the balance and not keep having such high monthly fees.<br>',
#  '  borrower added on 12/23/13 > to pay off my credit cards<br>',
#  '  borrower added on 12/23/13 > this loan is to eliminate and consolidate a couple credit card payments into one payment at a lower interest rate and give me piece of mind concerning any home repairs/improvements.<br>',
#  '  borrower added on 12/23/13 > pay off credit cards<br>',
#  '  borrower added on 12/23/13 > paying off my stupid credit cards and never having to worry about them again! they are awful!<br>',
#  '  borrower added on 12/25/13 > this loan will be used towards a 3 year debt reduction plan.<br>',
#  '  borrower added on 12/23/13 > to pay credit card and other loans and pay just one bill monthly to you.<br>',
#  '  borrower added on 12/23/13 > i would like to start the new year off right and consolidate some credit card debt so i can plan better for the future.<br>',
#  '  borrower added on 12/23/13 > pay off bills, reduce credit debt. time to do the honey dues<br>',
#  '  borrower added on 12/23/13 > debt be gone.<br>pay off balances of shredded credit cards.<br>',
#  "  borrower added on 12/23/13 > i want to consolidate my credits so i can only pay one account every month. it's hard to track down each credit cards specially when you work 10 to 12 hours every day and no day off. the money will ease my burden of checking all my accounts every month. thank you for your help and happy holiday!<br>",
#  '  borrower added on 12/23/13 > to pay credit cards.<br><br> borrower added on 12/23/13 > my loan is to pay off credit cards.<br>',
#  '  borrower added on 12/23/13 > i want to pay off all my credit cards with this loan so i can have only one bill and pay off debit sooner.<br>',
#  '  borrower added on 12/23/13 > debt consolidation- pay down credit cards-<br><br> borrower added on 12/23/13 > debt consolidation. pay down credit cards.<br>',
#  '  borrower added on 12/23/13 > i need this loan to pay down my credit card bills. i have so many other bills to take care of and paying down the credit card bills will allow me to focus on other things.<br>',
#  '  borrower added on 12/23/13 > to consolidate some high interest credit cards.<br>',
#  '  borrower added on 12/23/13 > to consolidate high interest credit cards<br>',
#  '  borrower added on 12/23/13 > i am paying of my credit card with the lending club.<br><br>  borrower added on 12/23/13 > i am paying off my credit card debt using the lending club. i find easier using this method than going to a traditional bank.<br><br> borrower added on 12/23/13 > i would make a good borrower because i have good credit and i always make my bills and payments on time.  i am also employed full time with a stable job as well.<br>',
#  '  borrower added on 12/23/13 > i have a charge card that i maxed out at 8,800 ! i dont charge no more and want this taken care of!<br><br> borrower added on 12/23/13 > also ill never miss a payment<br>',
#  "  borrower added on 12/23/13 > to consolidate crest cards making one payment will make life easier.<br><br>  borrower added on 12/23/13 > i've been employed with the same company for almost 22 years.<br><br> borrower added on 12/23/13 > i've been employed with the same company for almost 22 years.<br>",
#  '  borrower added on 12/23/13 > trying to reconsolidate higher rate credit after re modeling my home<br>',
#  "  borrower added on 12/23/13 > i have credit card debt from college. i have successfully paid down over half of a $20,000 balance, and recently my interest rates have gone up for no reason other than the banks wanted to charge more. no late payments, anything. they just decided to raise my rate. i'd like to pay them off. thanks<br>",
#  "  borrower added on 12/23/13 > got into some major credit card debt during college. between that and paying down my student loans, feels like i'll never get out of debt. i'm never late on payments, but the high interest is killing me. please help! thanks!<br>",
#  '  borrower added on 12/23/13 > would really like to consolidate some loans to help myself get out of debt faster, my number one goal in life it to become debt free and would appreciate the help in making this goal become a reality.<br>',
#  '  borrower added on 12/23/13 > this loan is to pay off all of my outstanding higher interest debts.  it will put me in a stronger financial position.<br>',
#  '  borrower added on 12/23/13 > i got a loan thru financial one but the interest rate is so high i would like to pay it off  and pay off credit card right now i am making two payments and it will take me twice as ling to pay these off if i do not get this loan<br>',
#  '  borrower added on 12/23/13 > i would like to consolidate all my bills to one payment for easier money management<br><br> borrower added on 12/23/13 > i want to consolidate small credit card bills to one payment<br><br> borrower added on 12/23/13 > i want to consolidate all credit card bills and place them under one payment.  i have a goal to grtt out of all consumer debt in 2014<br><br> borrower added on 12/23/13 > my 2014 financial goal is to eliminate all  consumer debt.  i believe i can accomplish this by managing 1 payment with 1 interest rate.<br>',
#  '  borrower added on 12/23/13 > loan will be used to pay highest rate credit card balance to zero.<br>',
#  '  borrower added on 12/24/13 > pay off higher interest rate credit cards and simplify a monthly payment.<br>',
#  '  borrower added on 12/23/13 > getting caught up over the holidays.<br>',
#  "  borrower added on 12/23/13 > this is the next step in getting debt under control.  refinanced the house at a much lower rate, bought a much-needed new car at 0.00 interest... now need to pay off the high-interest credit cards. thank you for your consideration.  may god's grace shine upon you.<br>",
#  '  borrower added on 12/23/13 > pay off 3 credit cards and be on time with loan payments with america first.  have never been late and want to leave rest in savings. have been at same job for 25 years.  have two kids in college.<br>',
#  '  borrower added on 12/23/13 > i am seeking additional funding for my business. currently would like to purchase inventory and equipment. i currently keep selling out of items faster than i can restock them. i would like to purchase a pallet of items and other items to keep ahead of the orders.<br>',
#  '  borrower added on 12/23/13 > pay off some credit cards<br>',
#  '  borrower added on 12/23/13 > consolidate credit card debt into one payment at lower interest rate<br>',
#  '  borrower added on 12/23/13 > my intentions for this loan are to pay off my debt, this includes my current credit cards and my loan through my bank.  i want to burden myself of some of this debt so that i can strengthen my credit to have a better future.<br>',
#  '  borrower added on 12/23/13 > working towards freedom<br>',
#  '  borrower added on 12/23/13 > this loan will help me to pay off credit card debt. i have never paid my credit cards late, and i always pay more than the minimum amount, but the balance seems to continue to climb. i am on the way to becoming debt free!<br>',
#  '  borrower added on 12/23/13 > i am seeking a loan to refinance/consolidate my credit card debt as i believe i can pay it off more quickly in one monthly payment.  my goal is to further inprove my credit score and continue saving for a down payment to purchase a condo or house in 5-7 years.<br>',
#  '  borrower added on 12/23/13 > daughters wedding<br>',
#  '  borrower added on 12/23/13 > i am just looking to consolidate 3 credit cards into one easy payment per month.  i am reliable and have never missed a payment on other accounts.<br>',
#  '  borrower added on 12/23/13 > medical bill<br>',
#  '  borrower added on 12/23/13 > debt consolidation from prior business ownership<br><br>  borrower added on 12/23/13 > will be used to debt consolidate for past business expenses associated with former ownership of llc which no longer exist<br>',
#  '  borrower added on 12/23/13 > consolidate bills for lower interest rate and quicker debt elimination<br>',
#  '  borrower added on 12/23/13 > planing on getting marry<br>',
#  '  borrower added on 12/23/13 > pay credit cards and get a lower interest rate<br>',
#  '  borrower added on 12/23/13 > easily paying current credit card debt/school loan but looking for a way to consolidate 4 payments into one.  by doing so i can make double payments on this loan monthly.<br><br> borrower added on 12/23/13 > current job: dream job and very stable<br>payments: by consolidating into one, i plan to make double payments<br>why fund me: i am dependable and pay my bills in full and on time<br>',
#  '  borrower added on 12/23/13 > i am looking to consolidate my debt to help maintain good credit. my utilization is to high and i want to stop use of credit cards and pay monthly to one lender. a payment of up to 500 is easy for me due to low overhead cost at home.<br>',
#  '  borrower added on 12/23/13 > various home improvement activities.<br>',
#  '  borrower added on 12/23/13 > debt consolidation ( credit cards )<br>',
#  '  borrower added on 12/23/13 > to consolidate my loan and credit cards for a lower monthly payment.<br>',
#  '  borrower added on 12/23/13 > to pay off medical bills and all credit card debt along with my auto loan.<br>',
#  '  borrower added on 12/23/13 > consolidating everything into one payment on one date. no more juggling when one thing is due and then the other. the freedom of having 1 due date on it all will even allow me to pay extra since i know its one thing and one thing only.<br>',
#  '  borrower added on 12/23/13 > i have credit cards i would like to condense, as well as a small balance to the irs<br>',
#  '  borrower added on 12/23/13 > to consolidates multiply debits.<br>',
#  '  borrower added on 12/23/13 > i will pay off several credit card obligations to save on finance charges and pay off the obligation sooner.<br>',
#  '  borrower added on 12/23/13 > i am just desperate to consolidate my debts! some are credit cards, some are small loans and medical bills. i am always good about paying my bills every month, but 1 bill would be so much better than 15 different ones! thank you for your help!!<br>',
#  '  borrower added on 12/23/13 > i have a stable, good paying job at a very good company. i work hard, pay my bills on time and manage my budget carefully.  i plan to use the funds to pay off a higher interest rate credit card balance. thank you.<br>',
#  '  borrower added on 12/23/13 > i am currently paying four credit and health cards at varying interest rates. i need to consolidate this amounts into one fixed payment at a favorable rate.<br>',
#  '  borrower added on 12/23/13 > i want to consolidate debt and have a lower overall interest rate then <br>what i currently pay combined. this is a great way to do that in a reasonable amount of time.<br>',
#  '  borrower added on 12/23/13 > credit card consolidation<br><br> borrower added on 12/23/13 > credit card consolidation<br><br> borrower added on 12/23/13 > credit card consolidation<br>',
#  '  borrower added on 12/23/13 > pay off higher interest loans<br>',
#  '  borrower added on 12/23/13 > loan #1<br>',
#  '  borrower added on 12/23/13 > debt consolidation<br>',
#  '  borrower added on 12/23/13 > payoff of credit cards.<br>',
#  '  borrower added on 12/23/13 > my loan is for dept consolidation<br>',
#  '  borrower added on 12/23/13 > i will pay off the previous lending club loan to achieve a lower interest rate, and payment, and leave some money to help my daughter to move<br>',
#  '  borrower added on 12/23/13 > personal loan needed to cover emergency expense for heating system.<br>',
#  "  borrower added on 12/23/13 > paying off a large cc bal with a higher int rt. other bals are low int. part of hi bal is work related exp so that's pd off monthly.  plan on paying off this loan in 18-24 mos.<br>",
#  '  borrower added on 12/23/13 > consolidation of credit cards<br>',
#  '  borrower added on 12/23/13 > this loan will be used to manage a timber and wildlife parcel for near future returns and parcel improvement.<br>',
#  '  borrower added on 12/23/13 > i am wanting to consolidate debt so that i have one single payment to one lender versus multiple credit card accounts.<br>',
#  '  borrower added on 12/23/13 > this loan will help shape my short- and long-term financial future! thank you for your consideration!<br>',
#  ...]

# %%
## TA/INSTRUCTOR ONLY
## MARK AWARDED: /1

# %% [markdown]
# ### Q4. Stop Words Removal
#
# To keep only relevant words, you will remove all stopwords from each description by using the `stopwords` corpus to remove them.
#
# Steps:
#
# 1. Create the list of stopwords in `english`
# 2. Tokenize the each description
# 3. Check for stopwords
# 4. Join up non stopwords as a string
#
# All steps, except step 1, must be done <b>within the same function.</b> Your function should return a string.
#
# Using the `apply()` method, create a new column called `desc_no_stopwords` to the `all_desc_df`.
#
# <b>Note: This part might take awhile to run (an average of 2 minutes).</b>
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/1fED4Uu.png">

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q5. Train Test Split
#
# Split your data up into training and testing sets using `sklearn.model_selection` with `train_test_split`, into 4 different variables, `x_train`, `x_test`, `y_train` and `y_test`, where:
#
# - <b>first</b> argument should be the `desc_cleaned` column but as a <b>DataFrame (2 square brackets)</b>
# - <b>second</b> argument should <b>only</b> be the `target` column
# - `random_state` is 0
# - `test_size` is 0.2

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q6. Vectorizer
#
# As you would be using the Naive Bayes Classifier, you would need to transform your description into a matrix of 1s and 0s. Use the `CountVectorizer` to transform your `desc_cleaned` into a matrix, called `desc_matrix`.

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q7. Multinomial Naive Bayes Classifier
#
# Create a new `MultinomialNB` classifer and name it as `desc_classifier`, then `.fit()` the vectorized matrix, `desc_matrix` and `y_train`.

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q8. Confusion Matrix
#
# Plot the confusion matrix for the Naive Bayes Classifier by:
#
# 1. Vectorizing (transform) the `x_test` of `desc_cleaned`
# 2. Using `.predict` on the vectorized set from the to get the test results
# 3. Use `sns.heatmap` to create confusion matrix
# 4. Set `.ylim()` to (2,0)
# 5. Set `.xlim()` to (0,2)
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/InjikTM.png">

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ## K-Means Clustering - 7 marks
#
# To discover more insights about the dataset, you decided to ran the K-means clustering algorithm to discover the different clusters that could form.
#
# ### Open Loans Data (Non-Description) File
#
# Open the `loans_transformed-200k.csv` as `all_loans_df`.

# %% [markdown]
# ### Q9. Integer Encoding
#
# Just as the above Integer Encoding question, create a new column called `target_int` where `Non Default` is `0` and `Default` is `1`.
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/D0VcNAs.png"/>

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q10. Reduce to Numerical Data
#
# For K-means algorithm to work properly, your dataframe should only contain numeric datasets. Also, you decide to <b>exclude</b> (drop) the `int_round` and `income_tax` columns are similar to the other columns too. Store this dataframe as `loans_numeric_df`.
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/80Ccldn.png">

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q11. Select Optimal K - Elbow Plot
#
# Plot the elbow plot by doing multiple iterations of the k-means algorithm, between a value of <b>2 to 15 (inclusive)</b>. Select a K that you think is appropriate to carry on in the next step.
#
# <b>Note: This will take about 2 minutes to compute finish all the Ks</b>
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/VQfZN86.png">

# %%
## TA/INSTRUCTOR ONLY
## PLOT MARK: /1

# %% [markdown]
# ### Q12. K-Means Clustering with Optimal K - 2 Marks
#
# Choose an <b>appropriate K</b> based on the chart above, then apply the k-means algorithm only once and store the model as `loans_kmeans`.
#
# Make sure `random_state` is 0.

# %%
## TA/INSTRUCTOR ONLY
## KMEANS MARK: /1
## SELECTING AN APPROPRIATE K - MARK: /1

# %% [markdown]
# ### Q13. Set Labels
#
# All loans are now tagged with a particular cluster or label. Using the `.labels_` attribute, create a new column called `label` to `all_loans_df`.
#
# **Expected Output:** (for k = 8)
#
# <img src="https://i.imgur.com/uKpialC.png">

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q14. Clustering Analysis
#
# Now that you've labelled each loans, you want know the <b>proportion of default loans</b> within each cluster
#
# **Expected Output:** (for k = 8)
#
#     label  target
#     0      Default        0.133062
#            Non Default    0.866938
#     1      Non Default    1.000000
#     2      Default        0.090717
#            Non Default    0.909283
#     3      Default        0.055154
#            Non Default    0.944846
#     4      Default        0.090909
#            Non Default    0.909091
#     5      Default        0.078544
#            Non Default    0.921456
#     6      Default        0.062500
#            Non Default    0.937500
#     7      Default        0.113032
#            Non Default    0.886968
#     dtype: float64

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ## Decision Tree Classifier - 3 marks
#
# ### Q15. Train Test Split
#
# Similar to how you did `train_test_split` on the Decision Tree Classifier, conduct `train_test_split` on the `loans_numeric_df`, into 4 different variables, `x_train`, `x_test`, `y_train` and `y_test`, where:
#
# - <b>first</b> argument should be all columns but <b>without</b> the `target_int` column as a <b>DataFrame</b>
# - <b>second</b> argument should <b>only</b> be the `target_int` column
# - `random_state` is 0
# - `test_size` is 0.2

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q16. Fit DecisionTree
#
# Using the `DecisionTreeClassifier`, create a new Decision Tree by using `.fit()` with the `x_train` and `y_train` variables. Name this classifier as `loans_clf`.
#
# <b>Note: `random_state` should be `0`.</b>

# %%
from sklearn import tree
loans_clf = tree.DecisionTreeClassifier(random_state=0)
loans_clf = loans_clf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f051645b19e8> in <module>
#       1 from sklearn import tree
#       2 loans_clf = tree.DecisionTreeClassifier(random_state=0)
# ----> 3 loans_clf = loans_clf.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q17. Confusion Matrix
#
# Plot the confusion matrix for the decision tree classifier by:
#
# 1. Using `.predict` on the `x_test` to get the test results
# 2. Use `sns.heatmap` to create confusion matrix
# 3. Set `.ylim()` to (2,0)
# 4. Set `.xlim()` to (0,2)
#
# **Expected Output:**
#
# <img src="https://i.imgur.com/JCRqzHp.png">

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ## Performance Measures - 2 marks
#
# ### Q18. Accuracy & Precision
#
# Based on the above confusion matrices, calculate, <b>with workings</b>, the <b>Accuracy and Precision</b> for the:
#
# 1. Naive Bayes Classifier
# 2. Decision Tree Classifier

# %%
# NAIVE BAYES CLASSIFIER 
# Accuracy = 
# Precision = 

# DECISION TREE
# Accuracy = 
# Precision =

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# ### Q19. Model Assessment
#
# After assessing the accuracy and precision scores, do you think that the models above are reliable in detecting default loans? Explain your answer.

# %%
# Answer:

# %%
## TA/INSTRUCTOR ONLY
## MARKS AWARDED: /1

# %% [markdown]
# <div class="alert alert-success">
# <b>Checkpoint</b>: When you have completed, upload your progress to eLearn. eLearn only accepts the latest notebooks so if you have an existing notebook, your latest upload will <b>override</b> it.
# </div>
